# %% [markdown]
# <a href="https://colab.research.google.com/github/sajjadshahkarami/twitterScrapper/blob/main/tweets_with_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import twint
import nest_asyncio
import datetime

# %%
nest_asyncio.apply()

# %%
conf=twint.Config()

# %%
conf.Lang="fa"
conf.Limit=5000
conf.Since='2021-10-01'
conf.Until='2021-10-30'
conf.Output="2021-10.csv"
conf.Store_csv=True

# %%
keys=open('new_keys.txt','r')

# %%
keywords=[]
for key in keys:
  keywords.append(key)

# %%
for key in keywords:
  conf.Search=str(key)
  twint.run.Search(conf)
# Out:
# 1454236323322150915 2021-10-29 23:58:52 +0000 <saeedsh86385958> از اقوام شروع کنید، اگر کسیو میشناسید، از هر طریقی که میتونید حتی با محبت یا آموزشی یا حتی گرفتن احوالش بدون حاشیه، یه جور که حس کنه یه خانواده گرم و با حال داره .
# 1454236210663153673 2021-10-29 23:58:25 +0000 <AliSardarzadeh> خوب مشخصه با خانواده خودشه
# 1454236203696496640 2021-10-29 23:58:24 +0000 <Miss_Moloud1998> @A_raefipur استاد رائفی پور بعد ساعت یک شب اصلا تبدیل به ی آدم دیگه میشن😂😂🤦🏻‍♀️ ولی کاملا حرفتون درسته چه اختلال های هورمونی که اسم عشق روش نزاشتن  تهشم یا به دادگاه خانواده رسید یا به افسردگی اما استااااااد موقع توییت زدن ی نگاه به ساعت بندازید خوووب😅🤦🏻‍♀️  https://t.co/cZpv6QChQh
# 1454235937332989956 2021-10-29 23:57:20 +0000 <GulaJanSahadat2> تو در فکر چی هستی خانواده های افغانستان از گرسنگی می میرد #آیا؟ بی غیر از تبریکی و تقبیح کردن چیزی دیگری را یاد دارید؟
# 1454235701743083529 2021-10-29 23:56:24 +0000 <prolter995> @Farzane95B @Salimeh_B والااا، خانواده نشسته، رعایت نمیکنن مردم🚶
# ...
